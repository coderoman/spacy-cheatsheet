# %% [markdown]
# # Tokenization
#
# Parsing text into tokens - words, punctuation or numbers

# %%
import re
import spacy
import pandas as pd

nlp = spacy.load('en_core_web_sm')

doc = nlp(open('./assets/sentence_got.txt').read())
chapter = nlp(open('./assets/chapter_got.txt').read())

print([token.text for token in doc])
# Out:
# ['“', 'We', 'should', 'start', 'back', ',', '”', 'Gared', 'urged', 'as', 'the', 'woods', 'began', 'to', 'grow', 'dark', 'around', 'them', '.', '\n', '“', 'The', 'wildlings', 'are', 'dead', '.', '”']

# %% [markdown]
# # Lemmatization
#
# Reducing tokens to it's base forms.

# %%
df = pd.DataFrame([(token.text, token.lemma_) for token in doc], columns=['Token', 'Lemma'])

df.style
# Out:
# <style type="text/css">
# </style>
# <table id="T_b9726_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Token</th>
#       <th class="col_heading level0 col1" >Lemma</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b9726_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_b9726_row0_col0" class="data row0 col0" >“</td>
#       <td id="T_b9726_row0_col1" class="data row0 col1" >"</td>
#     </tr>
#     <tr>
#       <th id="T_b9726_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_b9726_row1_col0" class="data row1 col0" >We</td>
#       <td id="T_b9726_row1_col1" class="data row1 col1" >we</td>
#     </tr>
#     <tr>
#       <th id="T_b9726_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_b9726_row2_col0" class="data row2 col0" >should</td>
#       <td id="T_b9726_row2_col1" class="data row2 col1" >should</td>
#     </tr>
#     <tr>
#       <th id="T_b9726_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_b9726_row3_col0" class="data row3 col0" >start</td>
#       <td id="T_b9726_row3_col1" class="data row3 col1" >start</td>
#     </tr>
#     <tr>
#       <th id="T_b9726_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_b9726_row4_col0" class="data row4 col0" >back</td>
#       <td id="T_b9726_row4_col1" class="data row4 col1" >back</td>
#     </tr>
#     <tr>
#       <th id="T_b9726_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_b9726_row5_col0" class="data row5 col0" >,</td>
#       <td id="T_b9726_row5_col1" class="data row5 col1" >,</td>
#     </tr>
#     <tr>
#       <th id="T_b9726_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_b9726_row6_col0" class="data row6 col0" >”</td>
#       <td id="T_b9726_row6_col1" class="data row6 col1" >"</td>
#     </tr>
#     <tr>
#       <th id="T_b9726_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_b9726_row7_col0" class="data row7 col0" >Gared</td>
#       <td id="T_b9726_row7_col1" class="data row7 col1" >Gared</td>
#     </tr>
#     <tr>
#       <th id="T_b9726_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_b9726_row8_col0" class="data row8 col0" >urged</td>
#       <td id="T_b9726_row8_col1" class="data row8 col1" >urge</td>
#     </tr>
#     <tr>
#       <th id="T_b9726_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_b9726_row9_col0" class="data row9 col0" >as</td>
#       <td id="T_b9726_row9_col1" class="data row9 col1" >as</td>
#     </tr>
#     <tr>
#       <th id="T_b9726_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_b9726_row10_col0" class="data row10 col0" >the</td>
#       <td id="T_b9726_row10_col1" class="data row10 col1" >the</td>
#     </tr>
#     <tr>
#       <th id="T_b9726_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_b9726_row11_col0" class="data row11 col0" >woods</td>
#       <td id="T_b9726_row11_col1" class="data row11 col1" >wood</td>
#     </tr>
#     <tr>
#       <th id="T_b9726_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_b9726_row12_col0" class="data row12 col0" >began</td>
#       <td id="T_b9726_row12_col1" class="data row12 col1" >begin</td>
#     </tr>
#     <tr>
#       <th id="T_b9726_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_b9726_row13_col0" class="data row13 col0" >to</td>
#       <td id="T_b9726_row13_col1" class="data row13 col1" >to</td>
#     </tr>
#     <tr>
#       <th id="T_b9726_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_b9726_row14_col0" class="data row14 col0" >grow</td>
#       <td id="T_b9726_row14_col1" class="data row14 col1" >grow</td>
#     </tr>
#     <tr>
#       <th id="T_b9726_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_b9726_row15_col0" class="data row15 col0" >dark</td>
#       <td id="T_b9726_row15_col1" class="data row15 col1" >dark</td>
#     </tr>
#     <tr>
#       <th id="T_b9726_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_b9726_row16_col0" class="data row16 col0" >around</td>
#       <td id="T_b9726_row16_col1" class="data row16 col1" >around</td>
#     </tr>
#     <tr>
#       <th id="T_b9726_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_b9726_row17_col0" class="data row17 col0" >them</td>
#       <td id="T_b9726_row17_col1" class="data row17 col1" >they</td>
#     </tr>
#     <tr>
#       <th id="T_b9726_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_b9726_row18_col0" class="data row18 col0" >.</td>
#       <td id="T_b9726_row18_col1" class="data row18 col1" >.</td>
#     </tr>
#     <tr>
#       <th id="T_b9726_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_b9726_row19_col0" class="data row19 col0" >
# </td>
#       <td id="T_b9726_row19_col1" class="data row19 col1" >
# </td>
#     </tr>
#     <tr>
#       <th id="T_b9726_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_b9726_row20_col0" class="data row20 col0" >“</td>
#       <td id="T_b9726_row20_col1" class="data row20 col1" >"</td>
#     </tr>
#     <tr>
#       <th id="T_b9726_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_b9726_row21_col0" class="data row21 col0" >The</td>
#       <td id="T_b9726_row21_col1" class="data row21 col1" >the</td>
#     </tr>
#     <tr>
#       <th id="T_b9726_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_b9726_row22_col0" class="data row22 col0" >wildlings</td>
#       <td id="T_b9726_row22_col1" class="data row22 col1" >wildling</td>
#     </tr>
#     <tr>
#       <th id="T_b9726_level0_row23" class="row_heading level0 row23" >23</th>
#       <td id="T_b9726_row23_col0" class="data row23 col0" >are</td>
#       <td id="T_b9726_row23_col1" class="data row23 col1" >be</td>
#     </tr>
#     <tr>
#       <th id="T_b9726_level0_row24" class="row_heading level0 row24" >24</th>
#       <td id="T_b9726_row24_col0" class="data row24 col0" >dead</td>
#       <td id="T_b9726_row24_col1" class="data row24 col1" >dead</td>
#     </tr>
#     <tr>
#       <th id="T_b9726_level0_row25" class="row_heading level0 row25" >25</th>
#       <td id="T_b9726_row25_col0" class="data row25 col0" >.</td>
#       <td id="T_b9726_row25_col1" class="data row25 col1" >.</td>
#     </tr>
#     <tr>
#       <th id="T_b9726_level0_row26" class="row_heading level0 row26" >26</th>
#       <td id="T_b9726_row26_col0" class="data row26 col0" >”</td>
#       <td id="T_b9726_row26_col1" class="data row26 col1" >"</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# # Coarse-grained part-of-speech
#
# Core parts of speech - noun, pronoun, determiner, adjective, verb, adverb, preposition, conjunction and interjection

# %%
pd.DataFrame([(token.text, token.pos_) for token in doc], columns=['Token','POS']).style
# Out:
# <style type="text/css">
# </style>
# <table id="T_7c879_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Token</th>
#       <th class="col_heading level0 col1" >POS</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7c879_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_7c879_row0_col0" class="data row0 col0" >“</td>
#       <td id="T_7c879_row0_col1" class="data row0 col1" >PUNCT</td>
#     </tr>
#     <tr>
#       <th id="T_7c879_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_7c879_row1_col0" class="data row1 col0" >We</td>
#       <td id="T_7c879_row1_col1" class="data row1 col1" >PRON</td>
#     </tr>
#     <tr>
#       <th id="T_7c879_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_7c879_row2_col0" class="data row2 col0" >should</td>
#       <td id="T_7c879_row2_col1" class="data row2 col1" >AUX</td>
#     </tr>
#     <tr>
#       <th id="T_7c879_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_7c879_row3_col0" class="data row3 col0" >start</td>
#       <td id="T_7c879_row3_col1" class="data row3 col1" >VERB</td>
#     </tr>
#     <tr>
#       <th id="T_7c879_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_7c879_row4_col0" class="data row4 col0" >back</td>
#       <td id="T_7c879_row4_col1" class="data row4 col1" >ADV</td>
#     </tr>
#     <tr>
#       <th id="T_7c879_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_7c879_row5_col0" class="data row5 col0" >,</td>
#       <td id="T_7c879_row5_col1" class="data row5 col1" >PUNCT</td>
#     </tr>
#     <tr>
#       <th id="T_7c879_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_7c879_row6_col0" class="data row6 col0" >”</td>
#       <td id="T_7c879_row6_col1" class="data row6 col1" >PUNCT</td>
#     </tr>
#     <tr>
#       <th id="T_7c879_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_7c879_row7_col0" class="data row7 col0" >Gared</td>
#       <td id="T_7c879_row7_col1" class="data row7 col1" >PROPN</td>
#     </tr>
#     <tr>
#       <th id="T_7c879_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_7c879_row8_col0" class="data row8 col0" >urged</td>
#       <td id="T_7c879_row8_col1" class="data row8 col1" >VERB</td>
#     </tr>
#     <tr>
#       <th id="T_7c879_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_7c879_row9_col0" class="data row9 col0" >as</td>
#       <td id="T_7c879_row9_col1" class="data row9 col1" >SCONJ</td>
#     </tr>
#     <tr>
#       <th id="T_7c879_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_7c879_row10_col0" class="data row10 col0" >the</td>
#       <td id="T_7c879_row10_col1" class="data row10 col1" >DET</td>
#     </tr>
#     <tr>
#       <th id="T_7c879_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_7c879_row11_col0" class="data row11 col0" >woods</td>
#       <td id="T_7c879_row11_col1" class="data row11 col1" >NOUN</td>
#     </tr>
#     <tr>
#       <th id="T_7c879_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_7c879_row12_col0" class="data row12 col0" >began</td>
#       <td id="T_7c879_row12_col1" class="data row12 col1" >VERB</td>
#     </tr>
#     <tr>
#       <th id="T_7c879_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_7c879_row13_col0" class="data row13 col0" >to</td>
#       <td id="T_7c879_row13_col1" class="data row13 col1" >PART</td>
#     </tr>
#     <tr>
#       <th id="T_7c879_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_7c879_row14_col0" class="data row14 col0" >grow</td>
#       <td id="T_7c879_row14_col1" class="data row14 col1" >VERB</td>
#     </tr>
#     <tr>
#       <th id="T_7c879_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_7c879_row15_col0" class="data row15 col0" >dark</td>
#       <td id="T_7c879_row15_col1" class="data row15 col1" >ADJ</td>
#     </tr>
#     <tr>
#       <th id="T_7c879_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_7c879_row16_col0" class="data row16 col0" >around</td>
#       <td id="T_7c879_row16_col1" class="data row16 col1" >ADP</td>
#     </tr>
#     <tr>
#       <th id="T_7c879_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_7c879_row17_col0" class="data row17 col0" >them</td>
#       <td id="T_7c879_row17_col1" class="data row17 col1" >PRON</td>
#     </tr>
#     <tr>
#       <th id="T_7c879_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_7c879_row18_col0" class="data row18 col0" >.</td>
#       <td id="T_7c879_row18_col1" class="data row18 col1" >PUNCT</td>
#     </tr>
#     <tr>
#       <th id="T_7c879_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_7c879_row19_col0" class="data row19 col0" >
# </td>
#       <td id="T_7c879_row19_col1" class="data row19 col1" >SPACE</td>
#     </tr>
#     <tr>
#       <th id="T_7c879_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_7c879_row20_col0" class="data row20 col0" >“</td>
#       <td id="T_7c879_row20_col1" class="data row20 col1" >PUNCT</td>
#     </tr>
#     <tr>
#       <th id="T_7c879_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_7c879_row21_col0" class="data row21 col0" >The</td>
#       <td id="T_7c879_row21_col1" class="data row21 col1" >DET</td>
#     </tr>
#     <tr>
#       <th id="T_7c879_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_7c879_row22_col0" class="data row22 col0" >wildlings</td>
#       <td id="T_7c879_row22_col1" class="data row22 col1" >NOUN</td>
#     </tr>
#     <tr>
#       <th id="T_7c879_level0_row23" class="row_heading level0 row23" >23</th>
#       <td id="T_7c879_row23_col0" class="data row23 col0" >are</td>
#       <td id="T_7c879_row23_col1" class="data row23 col1" >AUX</td>
#     </tr>
#     <tr>
#       <th id="T_7c879_level0_row24" class="row_heading level0 row24" >24</th>
#       <td id="T_7c879_row24_col0" class="data row24 col0" >dead</td>
#       <td id="T_7c879_row24_col1" class="data row24 col1" >ADJ</td>
#     </tr>
#     <tr>
#       <th id="T_7c879_level0_row25" class="row_heading level0 row25" >25</th>
#       <td id="T_7c879_row25_col0" class="data row25 col0" >.</td>
#       <td id="T_7c879_row25_col1" class="data row25 col1" >PUNCT</td>
#     </tr>
#     <tr>
#       <th id="T_7c879_level0_row26" class="row_heading level0 row26" >26</th>
#       <td id="T_7c879_row26_col0" class="data row26 col0" >”</td>
#       <td id="T_7c879_row26_col1" class="data row26 col1" >PUNCT</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# # Fine-grained part-of-speech
#
# [part-of-speech with morphological features](https://github.com/explosion/spaCy/blob/master/spacy/glossary.py) such as tenses and types of pronouns.

# %%
pd.DataFrame([(token.text, token.tag_, spacy.explain(token.tag_)) for token in doc], columns=['Token', 'tag_', 'Explanation.tag_']).style
# Out:
# <style type="text/css">
# </style>
# <table id="T_d596c_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Token</th>
#       <th class="col_heading level0 col1" >tag_</th>
#       <th class="col_heading level0 col2" >Explanation.tag_</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d596c_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_d596c_row0_col0" class="data row0 col0" >“</td>
#       <td id="T_d596c_row0_col1" class="data row0 col1" >``</td>
#       <td id="T_d596c_row0_col2" class="data row0 col2" >opening quotation mark</td>
#     </tr>
#     <tr>
#       <th id="T_d596c_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_d596c_row1_col0" class="data row1 col0" >We</td>
#       <td id="T_d596c_row1_col1" class="data row1 col1" >PRP</td>
#       <td id="T_d596c_row1_col2" class="data row1 col2" >pronoun, personal</td>
#     </tr>
#     <tr>
#       <th id="T_d596c_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_d596c_row2_col0" class="data row2 col0" >should</td>
#       <td id="T_d596c_row2_col1" class="data row2 col1" >MD</td>
#       <td id="T_d596c_row2_col2" class="data row2 col2" >verb, modal auxiliary</td>
#     </tr>
#     <tr>
#       <th id="T_d596c_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_d596c_row3_col0" class="data row3 col0" >start</td>
#       <td id="T_d596c_row3_col1" class="data row3 col1" >VB</td>
#       <td id="T_d596c_row3_col2" class="data row3 col2" >verb, base form</td>
#     </tr>
#     <tr>
#       <th id="T_d596c_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_d596c_row4_col0" class="data row4 col0" >back</td>
#       <td id="T_d596c_row4_col1" class="data row4 col1" >RB</td>
#       <td id="T_d596c_row4_col2" class="data row4 col2" >adverb</td>
#     </tr>
#     <tr>
#       <th id="T_d596c_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_d596c_row5_col0" class="data row5 col0" >,</td>
#       <td id="T_d596c_row5_col1" class="data row5 col1" >,</td>
#       <td id="T_d596c_row5_col2" class="data row5 col2" >punctuation mark, comma</td>
#     </tr>
#     <tr>
#       <th id="T_d596c_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_d596c_row6_col0" class="data row6 col0" >”</td>
#       <td id="T_d596c_row6_col1" class="data row6 col1" >''</td>
#       <td id="T_d596c_row6_col2" class="data row6 col2" >closing quotation mark</td>
#     </tr>
#     <tr>
#       <th id="T_d596c_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_d596c_row7_col0" class="data row7 col0" >Gared</td>
#       <td id="T_d596c_row7_col1" class="data row7 col1" >NNP</td>
#       <td id="T_d596c_row7_col2" class="data row7 col2" >noun, proper singular</td>
#     </tr>
#     <tr>
#       <th id="T_d596c_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_d596c_row8_col0" class="data row8 col0" >urged</td>
#       <td id="T_d596c_row8_col1" class="data row8 col1" >VBD</td>
#       <td id="T_d596c_row8_col2" class="data row8 col2" >verb, past tense</td>
#     </tr>
#     <tr>
#       <th id="T_d596c_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_d596c_row9_col0" class="data row9 col0" >as</td>
#       <td id="T_d596c_row9_col1" class="data row9 col1" >IN</td>
#       <td id="T_d596c_row9_col2" class="data row9 col2" >conjunction, subordinating or preposition</td>
#     </tr>
#     <tr>
#       <th id="T_d596c_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_d596c_row10_col0" class="data row10 col0" >the</td>
#       <td id="T_d596c_row10_col1" class="data row10 col1" >DT</td>
#       <td id="T_d596c_row10_col2" class="data row10 col2" >determiner</td>
#     </tr>
#     <tr>
#       <th id="T_d596c_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_d596c_row11_col0" class="data row11 col0" >woods</td>
#       <td id="T_d596c_row11_col1" class="data row11 col1" >NNS</td>
#       <td id="T_d596c_row11_col2" class="data row11 col2" >noun, plural</td>
#     </tr>
#     <tr>
#       <th id="T_d596c_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_d596c_row12_col0" class="data row12 col0" >began</td>
#       <td id="T_d596c_row12_col1" class="data row12 col1" >VBD</td>
#       <td id="T_d596c_row12_col2" class="data row12 col2" >verb, past tense</td>
#     </tr>
#     <tr>
#       <th id="T_d596c_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_d596c_row13_col0" class="data row13 col0" >to</td>
#       <td id="T_d596c_row13_col1" class="data row13 col1" >TO</td>
#       <td id="T_d596c_row13_col2" class="data row13 col2" >infinitival "to"</td>
#     </tr>
#     <tr>
#       <th id="T_d596c_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_d596c_row14_col0" class="data row14 col0" >grow</td>
#       <td id="T_d596c_row14_col1" class="data row14 col1" >VB</td>
#       <td id="T_d596c_row14_col2" class="data row14 col2" >verb, base form</td>
#     </tr>
#     <tr>
#       <th id="T_d596c_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_d596c_row15_col0" class="data row15 col0" >dark</td>
#       <td id="T_d596c_row15_col1" class="data row15 col1" >JJ</td>
#       <td id="T_d596c_row15_col2" class="data row15 col2" >adjective (English), other noun-modifier (Chinese)</td>
#     </tr>
#     <tr>
#       <th id="T_d596c_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_d596c_row16_col0" class="data row16 col0" >around</td>
#       <td id="T_d596c_row16_col1" class="data row16 col1" >IN</td>
#       <td id="T_d596c_row16_col2" class="data row16 col2" >conjunction, subordinating or preposition</td>
#     </tr>
#     <tr>
#       <th id="T_d596c_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_d596c_row17_col0" class="data row17 col0" >them</td>
#       <td id="T_d596c_row17_col1" class="data row17 col1" >PRP</td>
#       <td id="T_d596c_row17_col2" class="data row17 col2" >pronoun, personal</td>
#     </tr>
#     <tr>
#       <th id="T_d596c_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_d596c_row18_col0" class="data row18 col0" >.</td>
#       <td id="T_d596c_row18_col1" class="data row18 col1" >.</td>
#       <td id="T_d596c_row18_col2" class="data row18 col2" >punctuation mark, sentence closer</td>
#     </tr>
#     <tr>
#       <th id="T_d596c_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_d596c_row19_col0" class="data row19 col0" >
# </td>
#       <td id="T_d596c_row19_col1" class="data row19 col1" >_SP</td>
#       <td id="T_d596c_row19_col2" class="data row19 col2" >whitespace</td>
#     </tr>
#     <tr>
#       <th id="T_d596c_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_d596c_row20_col0" class="data row20 col0" >“</td>
#       <td id="T_d596c_row20_col1" class="data row20 col1" >``</td>
#       <td id="T_d596c_row20_col2" class="data row20 col2" >opening quotation mark</td>
#     </tr>
#     <tr>
#       <th id="T_d596c_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_d596c_row21_col0" class="data row21 col0" >The</td>
#       <td id="T_d596c_row21_col1" class="data row21 col1" >DT</td>
#       <td id="T_d596c_row21_col2" class="data row21 col2" >determiner</td>
#     </tr>
#     <tr>
#       <th id="T_d596c_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_d596c_row22_col0" class="data row22 col0" >wildlings</td>
#       <td id="T_d596c_row22_col1" class="data row22 col1" >NNS</td>
#       <td id="T_d596c_row22_col2" class="data row22 col2" >noun, plural</td>
#     </tr>
#     <tr>
#       <th id="T_d596c_level0_row23" class="row_heading level0 row23" >23</th>
#       <td id="T_d596c_row23_col0" class="data row23 col0" >are</td>
#       <td id="T_d596c_row23_col1" class="data row23 col1" >VBP</td>
#       <td id="T_d596c_row23_col2" class="data row23 col2" >verb, non-3rd person singular present</td>
#     </tr>
#     <tr>
#       <th id="T_d596c_level0_row24" class="row_heading level0 row24" >24</th>
#       <td id="T_d596c_row24_col

# %% [markdown]
# # Find quotes

# %%
for sentence in chapter.sents:
    quotes = re.findall(r"“(.*?)”", str(sentence))
    
    if len(quotes):
        print(quotes)
# Out:
# ['We should start back,']
# ['The wildlings are dead.']
# ['Do the dead frighten you?']
# ['Dead is dead,']
# ['Are they dead?']
# ['What proof have we?']
# ['Will saw them,']
# ['If he says they are dead, that’s proof enough for me.']
# ['My wet nurse said the same thing, Will,']
# ['We have a long ride before us,']
# ['Bet he killed them all himself, he did,', 'twisted their little heads off, our mighty warrior.']

# %% [markdown]
# # Syntactic Relations

# %% [markdown]
# Shows syntactic relations between tokens in sentence and connects pairs of words with a single arc.

# %%
pd.DataFrame([(token.head.text, token.text, token.dep_, spacy.explain(token.dep_) ) for token in doc], columns=['Head','text', 'dep_', 'explanation']).style
# Out:
# <style type="text/css">
# </style>
# <table id="T_e3add_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Head</th>
#       <th class="col_heading level0 col1" >text</th>
#       <th class="col_heading level0 col2" >dep_</th>
#       <th class="col_heading level0 col3" >explanation</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e3add_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_e3add_row0_col0" class="data row0 col0" >urged</td>
#       <td id="T_e3add_row0_col1" class="data row0 col1" >“</td>
#       <td id="T_e3add_row0_col2" class="data row0 col2" >punct</td>
#       <td id="T_e3add_row0_col3" class="data row0 col3" >punctuation</td>
#     </tr>
#     <tr>
#       <th id="T_e3add_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_e3add_row1_col0" class="data row1 col0" >start</td>
#       <td id="T_e3add_row1_col1" class="data row1 col1" >We</td>
#       <td id="T_e3add_row1_col2" class="data row1 col2" >nsubj</td>
#       <td id="T_e3add_row1_col3" class="data row1 col3" >nominal subject</td>
#     </tr>
#     <tr>
#       <th id="T_e3add_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_e3add_row2_col0" class="data row2 col0" >start</td>
#       <td id="T_e3add_row2_col1" class="data row2 col1" >should</td>
#       <td id="T_e3add_row2_col2" class="data row2 col2" >aux</td>
#       <td id="T_e3add_row2_col3" class="data row2 col3" >auxiliary</td>
#     </tr>
#     <tr>
#       <th id="T_e3add_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_e3add_row3_col0" class="data row3 col0" >urged</td>
#       <td id="T_e3add_row3_col1" class="data row3 col1" >start</td>
#       <td id="T_e3add_row3_col2" class="data row3 col2" >ccomp</td>
#       <td id="T_e3add_row3_col3" class="data row3 col3" >clausal complement</td>
#     </tr>
#     <tr>
#       <th id="T_e3add_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_e3add_row4_col0" class="data row4 col0" >start</td>
#       <td id="T_e3add_row4_col1" class="data row4 col1" >back</td>
#       <td id="T_e3add_row4_col2" class="data row4 col2" >advmod</td>
#       <td id="T_e3add_row4_col3" class="data row4 col3" >adverbial modifier</td>
#     </tr>
#     <tr>
#       <th id="T_e3add_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_e3add_row5_col0" class="data row5 col0" >urged</td>
#       <td id="T_e3add_row5_col1" class="data row5 col1" >,</td>
#       <td id="T_e3add_row5_col2" class="data row5 col2" >punct</td>
#       <td id="T_e3add_row5_col3" class="data row5 col3" >punctuation</td>
#     </tr>
#     <tr>
#       <th id="T_e3add_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_e3add_row6_col0" class="data row6 col0" >urged</td>
#       <td id="T_e3add_row6_col1" class="data row6 col1" >”</td>
#       <td id="T_e3add_row6_col2" class="data row6 col2" >punct</td>
#       <td id="T_e3add_row6_col3" class="data row6 col3" >punctuation</td>
#     </tr>
#     <tr>
#       <th id="T_e3add_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_e3add_row7_col0" class="data row7 col0" >urged</td>
#       <td id="T_e3add_row7_col1" class="data row7 col1" >Gared</td>
#       <td id="T_e3add_row7_col2" class="data row7 col2" >nsubj</td>
#       <td id="T_e3add_row7_col3" class="data row7 col3" >nominal subject</td>
#     </tr>
#     <tr>
#       <th id="T_e3add_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_e3add_row8_col0" class="data row8 col0" >urged</td>
#       <td id="T_e3add_row8_col1" class="data row8 col1" >urged</td>
#       <td id="T_e3add_row8_col2" class="data row8 col2" >ROOT</td>
#       <td id="T_e3add_row8_col3" class="data row8 col3" >None</td>
#     </tr>
#     <tr>
#       <th id="T_e3add_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_e3add_row9_col0" class="data row9 col0" >began</td>
#       <td id="T_e3add_row9_col1" class="data row9 col1" >as</td>
#       <td id="T_e3add_row9_col2" class="data row9 col2" >mark</td>
#       <td id="T_e3add_row9_col3" class="data row9 col3" >marker</td>
#     </tr>
#     <tr>
#       <th id="T_e3add_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_e3add_row10_col0" class="data row10 col0" >woods</td>
#       <td id="T_e3add_row10_col1" class="data row10 col1" >the</td>
#       <td id="T_e3add_row10_col2" class="data row10 col2" >det</td>
#       <td id="T_e3add_row10_col3" class="data row10 col3" >determiner</td>
#     </tr>
#     <tr>
#       <th id="T_e3add_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_e3add_row11_col0" class="data row11 col0" >began</td>
#       <td id="T_e3add_row11_col1" class="data row11 col1" >woods</td>
#       <td id="T_e3add_row11_col2" class="data row11 col2" >nsubj</td>
#       <td id="T_e3add_row11_col3" class="data row11 col3" >nominal subject</td>
#     </tr>
#     <tr>
#       <th id="T_e3add_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_e3add_row12_col0" class="data row12 col0" >urged</td>
#       <td id="T_e3add_row12_col1" class="data row12 col1" >began</td>
#       <td id="T_e3add_row12_col2" class="data row12 col2" >advcl</td>
#       <td id="T_e3add_row12_col3" class="data row12 col3" >adverbial clause modifier</td>
#     </tr>
#     <tr>
#       <th id="T_e3add_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_e3add_row13_col0" class="data row13 col0" >grow</td>
#       <td id="T_e3add_row13_col1" class="data row13 col1" >to</td>
#       <td id="T_e3add_row13_col2" class="data row13 col2" >aux</td>
#       <td id="T_e3add_row13_col3" class="data row13 col3" >auxiliary</td>
#     </tr>
#     <tr>
#       <th id="T_e3add_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_e3add_row14_col0" class="data row14 col0" >began</td>
#       <td id="T_e3add_row14_col1" class="data row14 col1" >grow</td>
#       <td id="T_e3add_row14_col2" class="data row14 col2" >xcomp</td>
#       <td id="T_e3add_row14_col3" class="data row14 col3" >open clausal complement</td>
#     </tr>
#     <tr>
#       <th id="T_e3add_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_e3add_row15_col0" class="data row15 col0" >grow</td>
#       <td id="T_e3add_row15_col1" class="data row15 col1" >dark</td>
#       <td id="T_e3add_row15_col2" class="data row15 col2" >acomp</td>
#       <td id="T_e3add_row15_col3" class="data row15 col3" >adjectival complement</td>
#     </tr>
#     <tr>
#       <th id="T_e3add_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_e3add_row16_col0" class="data row16 col0" >grow</td>
#       <td id="T_e3add_row16_col1" class="data row16 col1" >around</td>
#       <td id="T_e3add_row16_col2" class="data row16 col2" >prep</td>
#       <td id="T_e3add_row16_col3" class="data row16 col3" >prepositional modifier</td>
#     </tr>
#     <tr>
#       <th id="T_e3add_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_e3add_row17_col0" class="data row17 col0" >around</td>
#       <td id="T_e3add_row17_col1" class="data row17 col1" >them</td>
#       <td id="T_e3add_row17_col2" class="data row17 col2" >pobj</td>
#       <td id="T_e3add_row17_col3" class="data row17 col3" >object of preposition</td>
#     </tr>
#     <tr>
#       <th id="T_e3add_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_e3add_row18_col0" class="data row18 col0" >urged</td>
#       <td id="T_e3add_row18_col1" class="data row18 col1" >.</td>
#       <td id="T_e3add_row18_col2" class="data row18 col2" >punct</td>
#       <td id="T_e3add_row18_col3" class="data row18 col3" >punctuation</td>
#     </tr>
#     <tr>
#       <th id="T_e3add_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_e3add_row19_col0" class="data row19 col0" >
# </td>
#       <td id="T_e3add_row19_col1" class="data row19 col1" >
# </td>
#       <td id="T_e3add_row19_col2" class="data row19 col2" >dep</td>
#       <td id="T_e3add_row19_col3" class="data row19 col3" >unclassified dependent</td>
#     </tr>
#     <tr>
#       <th id="T_e3add_level0_row20" class="row

# %% [markdown]
# Extract description of money

# %%
phrase = nlp(u"Taiwan Semiconductor Manufacturing Co. on Tuesday, 6 december, to announce the opening of a second chip plant in Arizona, raising the company’s investment in the state from $12 billion to $40 billion.")

def extract():
    extraction = ''
    if token.tag_ == '$':
        extraction = token.text
        nextToken = token.i + 1
        while phrase[nextToken].tag_ == 'CD':
            extraction += phrase[nextToken].text + ' '
            nextToken += 1
        print(extraction)
     
for token in phrase:
    extract()

pd.DataFrame([(token.text, token.tag_, token.pos_, spacy.explain(token.tag_), spacy.explain(token.pos_)) for token in phrase], columns=['text', 'tag_', 'pos_', 'expl.tag_', 'expl.pos_'])
# Out:
# $12 billion
# $40 billion
#              text tag_   pos_  \
# 0          Taiwan  NNP  PROPN
# 1   Semiconductor  NNP  PROPN
# 2   Manufacturing  NNP  PROPN
# 3             Co.  NNP  PROPN
# 4              on   IN    ADP
# 5         Tuesday  NNP  PROPN
# 6               ,    ,  PUNCT
# 7               6   CD    NUM
# 8        december  NNP  PROPN
# 9               ,    ,  PUNCT
# 10             to   TO   PART
# 11       announce   VB   VERB
# 12            the   DT    DET
# 13        opening   NN   NOUN
# 14             of   IN    ADP
# 15              a   DT    DET
# 16         second   JJ    ADJ
# 17           chip   NN   NOUN
# 18          plant   NN   NOUN
# 19             in   IN    ADP
# 20        Arizona  NNP  PROPN
# 21              ,    ,  PUNCT
# 22        raising  VBG   VERB
# 23            the   DT    DET
# 24        company   NN   NOUN
# 25             ’s  POS   PART
# 26     investment   NN   NOUN
# 27             in   IN    ADP
# 28            the   DT    DET
# 29          state   NN   NOUN
# 30           from   IN    ADP
# 31              $    $    SYM
# 32             12   CD    NUM
# 33        billion   CD    NUM
# 34             to   TO   PART
# 35              $    $    SYM
# 36             40   CD    NUM
# 37        billion   CD    NUM
# 38              .    .  PUNCT
#
#                                             expl.tag_    expl.pos_
# 0                               noun, proper singular  proper noun
# 1                               noun, proper singular  proper noun
# 2                               noun, proper singular  proper noun
# 3                               noun, proper singular  proper noun
# 4           conjunction, subordinating or preposition   adposition
# 5                               noun, proper singular  proper noun
# 6                             punctuation mark, comma  punctuation
# 7                                     cardinal number      numeral
# 8                               noun, proper singular  proper noun
# 9                             punctuation mark, comma  punctuation
# 10                                   infinitival "to"     particle
# 11                                    verb, base form         verb
# 12                                         determiner   determiner
# 13                             noun, singular or mass         noun
# 14          conjunction, subordinating or preposition   adposition
# 15                                         determiner   determiner
# 16  adjective (English), other noun-modifier (Chin...    adjective
# 17                             noun, singular or mass         noun
# 18                             noun, singular or mass         noun
# 19          conjunction, subordinating or preposition   adposition
# 20                              noun, proper singular  proper noun
# 21                            punctuation mark, comma  punctuation
# 22                 verb, gerund or present participle         verb
# 23                                         determiner   determiner
# 24                             noun, singular or mass         noun
# 25                                  possessive ending     particle
# 26                             noun, singular or mass         noun
# 27          conjunction, subordinating or preposition   adposition
# 28                                         determiner   determiner
# 29                             noun, singular or mass         noun
# 30          conjunction, subordinating or preposition   adposition
# 31                                   symbol, currency       symbol
# 32                                    cardinal number      numeral
# 33                                    cardinal number      numeral
# 34                                   infinitival "to"     particle
# 35                                   symbol, currency       symbol
# 36                                    cardinal number      numeral
# 37                                    cardinal number      numeral
# 38                  punctuation mark, sentence closer  punctuation
